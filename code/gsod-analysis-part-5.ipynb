# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/samerens/Downloads/isd-history.txt', delimiter = '\t')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df = pd.read_csv('/Users/samerens/Downloads/isd-history.txt', delimiter = '\t')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
with open('/Users/samerens/Downloads/isd-history.txt', mode = 'r') as file: data = file.readlines()

# %%
data
# Out:
# ['USAF   WBAN  STATION NAME                  CTRY ST CALL  LAT     LON      ELEV(M) BEGIN    END\n',
#  '007018 99999 WXPOD 7018                                  +00.000 +000.000 +7018.0 20110309 20130730\n',
#  '007026 99999 WXPOD 7026                    AF            +00.000 +000.000 +7026.0 20120713 20170822\n',
#  '007070 99999 WXPOD 7070                    AF            +00.000 +000.000 +7070.0 20140923 20150926\n',
#  '008260 99999 WXPOD8270                                   +00.000 +000.000 +0000.0 20050101 20120731\n',
#  '008268 99999 WXPOD8278                     AF            +32.950 +065.567 +1156.7 20100519 20120323\n',
#  '008307 99999 WXPOD 8318                    AF            +00.000 +000.000 +8318.0 20100421 20100421\n',
#  '008411 99999 XM20                                                                 20160217 20160217\n',
#  '008414 99999 XM18                                                                 20160216 20160217\n',
# ...

# %%
data = data[1:]

# %%
usaf = [array[0] for array in [line.split(' ') for line in data]]

# %%
usaf
# Out:
# ['007018',
#  '007026',
#  '007070',
#  '008260',
#  '008268',
#  '008307',
#  '008411',
#  '008414',
#  '008415',
#  '008418',
#  '010000',
#  '010010',
#  '010013',
#  '010014',
#  '010015',
#  '010016',
#  '010017',
#  '010020',
#  '010030',
#  '010040',
#  '010050',
#  '010060',
#  '010070',
#  '010071',
#  '010080',
#  '010090',
#  '010100',
#  '010110',
#  '010120',
#  '010140',
#  '010150',
#  '010160',
#  '010170',
#  '010171',
#  '010190',
#  '010200',
#  '010230',
#  '010231',
#  '010240',
#  '010250',
#  '010260',
#  '010270',
#  '010280',
#  '010300',
#  '010303',
#  '010320',
#  '010330',
#  '010340',
#  '010350',
#  '010360',
#  '010361',
#  '010370',
#  '010400',
#  '010410',
#  '010420',
#  '010430',
#  '010431',
#  '010435',
#  '010440',
#  '010450',
#  '010455',
#  '010460',
#  '010470',
#  '010490',
#  '010510',
#  '010520',
#  '010530',
#  '010550',
#  '010570',
#  '010580',
#  '010590',
#  '010610',
#  '010617',
#  '010620',
#  '010630',
#  '010650',
# ...

# %%
import numpy as np

# %%
np.array(usaf).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 np.array(usaf).unique()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unique'

# %%
list(np.unique(usaf))
# Out:
# ['007018',
#  '007026',
#  '007070',
#  '008260',
#  '008268',
#  '008307',
#  '008411',
#  '008414',
#  '008415',
#  '008418',
#  '010000',
#  '010010',
#  '010013',
#  '010014',
#  '010015',
#  '010016',
#  '010017',
#  '010020',
#  '010030',
#  '010040',
#  '010050',
#  '010060',
#  '010070',
#  '010071',
#  '010080',
#  '010090',
#  '010100',
#  '010110',
#  '010120',
#  '010140',
#  '010150',
#  '010160',
#  '010170',
#  '010171',
#  '010190',
#  '010200',
#  '010230',
#  '010231',
#  '010240',
#  '010250',
#  '010260',
#  '010270',
#  '010280',
#  '010300',
#  '010303',
#  '010320',
#  '010330',
#  '010340',
#  '010350',
#  '010360',
#  '010361',
#  '010370',
#  '010400',
#  '010410',
#  '010420',
#  '010430',
#  '010431',
#  '010435',
#  '010440',
#  '010450',
#  '010455',
#  '010460',
#  '010470',
#  '010490',
#  '010510',
#  '010520',
#  '010530',
#  '010550',
#  '010570',
#  '010580',
#  '010590',
#  '010610',
#  '010617',
#  '010620',
#  '010630',
#  '010650',
# ...

# %%
lines = [line.split(' ') for line in data]

# %%
lines
# Out:
# [['007018',
#   '99999',
#   'WXPOD',
#   '7018',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '+00.000',
#   '+000.000',
#   '+7018.0',
#   '20110309',
#   '20130730\n'],
#  ['007026',
#   '99999',
#   'WXPOD',
#   '7026',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'AF',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '+00.000',
#   '+000.000',
#   '+7026.0',
#   '20120713',
#   '20170822\n'],
#  ['007070',
#   '99999',
#   'WXPOD',
#   '7070',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'AF',
# ...

# %%
wban = [line[1] for line in lines]

# %%
np.unique(wban)
# Out:
# array(['00001', '00002', '00003', ..., '96408', '96409', '99999'],
#       dtype='<U5')

# %%
data
# Out:
# ['007018 99999 WXPOD 7018                                  +00.000 +000.000 +7018.0 20110309 20130730\n',
#  '007026 99999 WXPOD 7026                    AF            +00.000 +000.000 +7026.0 20120713 20170822\n',
#  '007070 99999 WXPOD 7070                    AF            +00.000 +000.000 +7070.0 20140923 20150926\n',
#  '008260 99999 WXPOD8270                                   +00.000 +000.000 +0000.0 20050101 20120731\n',
#  '008268 99999 WXPOD8278                     AF            +32.950 +065.567 +1156.7 20100519 20120323\n',
#  '008307 99999 WXPOD 8318                    AF            +00.000 +000.000 +8318.0 20100421 20100421\n',
#  '008411 99999 XM20                                                                 20160217 20160217\n',
#  '008414 99999 XM18                                                                 20160216 20160217\n',
#  '008415 99999 XM21                                                                 20160217 20200314\n',
# ...

# %%
len(data)
# Out:
# 29610

# %%
countries = pd.read_csv('/ftp.ncdc.noaa.gov/gsod/country-list.txt', sep = ' ')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 countries = pd.read_csv('/ftp.ncdc.noaa.gov/gsod/country-list.txt', sep = ' ')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
with open('http://www.samerens.com/index.html', mode = 'r') as file: document = file.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 with open('http://www.samerens.com/index.html', mode = 'r') as file: document = file.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'http://www.samerens.com/index.html'

# %%
pd.read_csv('isd-history.txt', delim_whitespace = True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 pd.read_csv('isd-history.txt', delim_whitespace = True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
pd.read_csv('country-list.txt', delimiter = '\t')
# Out:
#                               FIPS ID     COUNTRY NAME
# 0    AA          ARUBA                             ...
# 1    AC          ANTIGUA AND BARBUDA               ...
# 2    AF          AFGHANISTAN                       ...
# 3    AG          ALGERIA                           ...
# 4    AI          ASCENSION ISLAND                  ...
# ..                                                 ...
# 283  YY          ST. MARTEEN, ST. EUSTATIUS, AND SA...
# 284  ZA          ZAMBIA                            ...
# 285  ZI          ZIMBABWE                          ...
# 286  ZM          SAMOA                             ...
# 287  ZZ          ST. MARTIN AND ST. BARTHOLOMEW    ...
#
# [288 rows x 1 columns]

# %%
with open('country-list.txt', mode = 'r') as file: lines = file.readlines()

# %%
lines
# Out:
# ['FIPS ID     COUNTRY NAME\n',
#  '\n',
#  'AA          ARUBA                                                                           \n',
#  'AC          ANTIGUA AND BARBUDA                                                             \n',
#  'AF          AFGHANISTAN                                                                     \n',
#  'AG          ALGERIA                                                                         \n',
#  'AI          ASCENSION ISLAND                                                                \n',
#  'AJ          AZERBAIJAN                                                                      \n',
#  'AL          ALBANIA                                                                         \n',
#  'AM          ARMENIA                                                                         \n',
#  'AN          ANDORRA                                                                         \n',
# ...

# %%
lines = lines[1:]

# %%
[line.split(' ') for line in lines]
# Out:
# [['AA',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ARUBA',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '\n'],
#  ['AC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ANTIGUA',
#   'AND',
#   'BARBUDA',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...

# %%
lines
# Out:
# ['AA          ARUBA                                                                           \n',
#  'AC          ANTIGUA AND BARBUDA                                                             \n',
#  'AF          AFGHANISTAN                                                                     \n',
#  'AG          ALGERIA                                                                         \n',
#  'AI          ASCENSION ISLAND                                                                \n',
#  'AJ          AZERBAIJAN                                                                      \n',
#  'AL          ALBANIA                                                                         \n',
#  'AM          ARMENIA                                                                         \n',
#  'AN          ANDORRA                                                                         \n',
# ...

# %%
iso_dict = dict([line.strip().split('          ') for line in lines])

# %%
iso_dict
# Out:
# {'AA': 'ARUBA',
#  'AC': 'ANTIGUA AND BARBUDA',
#  'AF': 'AFGHANISTAN',
#  'AG': 'ALGERIA',
#  'AI': 'ASCENSION ISLAND',
#  'AJ': 'AZERBAIJAN',
#  'AL': 'ALBANIA',
#  'AM': 'ARMENIA',
#  'AN': 'ANDORRA',
#  'AO': 'ANGOLA',
#  'AQ': 'AMERICAN SAMOA',
#  'AR': 'ARGENTINA',
#  'AS': 'AUSTRALIA',
#  'AT': 'ASHMORE AND CARTIER ISLANDS',
#  'AU': 'AUSTRIA',
#  'AV': 'ANGUILLA',
#  'AX': 'ANTIGUA, ST. KITTS, NEVIS, BARBUDA',
#  'AY': 'ANTARCTICA',
#  'AZ': 'AZORES',
#  'BA': 'BAHRAIN',
#  'BB': 'BARBADOS',
#  'BC': 'BOTSWANA',
#  'BD': 'BERMUDA',
#  'BE': 'BELGIUM',
#  'BF': 'BAHAMAS THE',
#  'BG': 'BANGLADESH',
#  'BH': 'BELIZE',
#  'BK': 'BOSNIA AND HERZEGOVINA',
#  'BL': 'BOLIVIA',
#  'BM': 'BURMA',
#  'BN': 'BENIN',
#  'BO': 'BELARUS',
#  'BP': 'SOLOMON ISLANDS',
#  'BQ': 'NAVASSA ISLAND',
#  'BR': 'BRAZIL',
#  'BS': 'BASSAS DA INDIA',
#  'BT': 'BHUTAN',
#  'BU': 'BULGARIA',
#  'BV': 'BOUVET ISLAND',
#  'BX': 'BRUNEI',
#  'BY': 'BURUNDI',
#  'BZ': 'BELGIUM AND LUXEMBOURG',
# ...

# %%
usaf
# Out:
# ['007018',
#  '007026',
#  '007070',
#  '008260',
#  '008268',
#  '008307',
#  '008411',
#  '008414',
#  '008415',
#  '008418',
#  '010000',
#  '010010',
#  '010013',
#  '010014',
#  '010015',
#  '010016',
#  '010017',
#  '010020',
#  '010030',
#  '010040',
#  '010050',
#  '010060',
#  '010070',
#  '010071',
#  '010080',
#  '010090',
#  '010100',
#  '010110',
#  '010120',
#  '010140',
#  '010150',
#  '010160',
#  '010170',
#  '010171',
#  '010190',
#  '010200',
#  '010230',
#  '010231',
#  '010240',
#  '010250',
#  '010260',
#  '010270',
#  '010280',
#  '010300',
#  '010303',
#  '010320',
#  '010330',
#  '010340',
#  '010350',
#  '010360',
#  '010361',
#  '010370',
#  '010400',
#  '010410',
#  '010420',
#  '010430',
#  '010431',
#  '010435',
#  '010440',
#  '010450',
#  '010455',
#  '010460',
#  '010470',
#  '010490',
#  '010510',
#  '010520',
#  '010530',
#  '010550',
#  '010570',
#  '010580',
#  '010590',
#  '010610',
#  '010617',
#  '010620',
#  '010630',
#  '010650',
# ...

# %%
wban
# Out:
# ['99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
# ...

# %%
with open('isd-history.txt', mode = 'r') as file: lines = file.readlines()

# %%
lines
# Out:
# ['USAF   WBAN  STATION NAME                  CTRY ST CALL  LAT     LON      ELEV(M) BEGIN    END\n',
#  '007018 99999 WXPOD 7018                                  +00.000 +000.000 +7018.0 20110309 20130730\n',
#  '007026 99999 WXPOD 7026                    AF            +00.000 +000.000 +7026.0 20120713 20170822\n',
#  '007070 99999 WXPOD 7070                    AF            +00.000 +000.000 +7070.0 20140923 20150926\n',
#  '008260 99999 WXPOD8270                                   +00.000 +000.000 +0000.0 20050101 20120731\n',
#  '008268 99999 WXPOD8278                     AF            +32.950 +065.567 +1156.7 20100519 20120323\n',
#  '008307 99999 WXPOD 8318                    AF            +00.000 +000.000 +8318.0 20100421 20100421\n',
#  '008411 99999 XM20                                                                 20160217 20160217\n',
#  '008414 99999 XM18                                                                 20160216 20160217\n',
# ...

# %%
lines = lines[1:]

# %%
lines
# Out:
# ['007018 99999 WXPOD 7018                                  +00.000 +000.000 +7018.0 20110309 20130730\n',
#  '007026 99999 WXPOD 7026                    AF            +00.000 +000.000 +7026.0 20120713 20170822\n',
#  '007070 99999 WXPOD 7070                    AF            +00.000 +000.000 +7070.0 20140923 20150926\n',
#  '008260 99999 WXPOD8270                                   +00.000 +000.000 +0000.0 20050101 20120731\n',
#  '008268 99999 WXPOD8278                     AF            +32.950 +065.567 +1156.7 20100519 20120323\n',
#  '008307 99999 WXPOD 8318                    AF            +00.000 +000.000 +8318.0 20100421 20100421\n',
#  '008411 99999 XM20                                                                 20160217 20160217\n',
#  '008414 99999 XM18                                                                 20160216 20160217\n',
#  '008415 99999 XM21                                                                 20160217 20200314\n',
# ...

# %%
len('007018 99999 ')
# Out:
# 13

# %%
len('BOGUS NORWAY                  ')
# Out:
# 30

# %%
stations = [line[13:43].strip() for line in lines]

# %%
stations
# Out:
# ['WXPOD 7018',
#  'WXPOD 7026',
#  'WXPOD 7070',
#  'WXPOD8270',
#  'WXPOD8278',
#  'WXPOD 8318',
#  'XM20',
#  'XM18',
#  'XM21',
#  'XM24',
#  'BOGUS NORWAY',
#  'JAN MAYEN(NOR-NAVY)',
#  'ROST',
#  'SORSTOKKEN',
#  'BRINGELAND',
#  'RORVIK/RYUM',
#  'FRIGG',
#  'VERLEGENHUKEN',
#  'HORNSUND',
#  'NY-ALESUND II',
#  'ISFJORD RADIO',
#  'EDGEOYA',
#  'NY-ALESUND',
#  'LONGYEARBYEN',
#  'LONGYEAR',
#  'KARL XII OYA',
#  'ANDOYA',
#  'KVITOYA',
#  '',
#  'SENJA-LAUKHELLA',
#  'HEKKINGEN FYR',
#  'KONGSOYA',
#  'AKSELOYA',
#  'GIBOSTAD',
#  'SVARTTANGEN',
#  'SORKAPPOYA',
#  'BARDUFOSS',
#  'DRAUGEN',
#  'PYRAMIDEN',
#  'TROMSO',
#  'TROMSO',
#  'TROMSO-HOLT',
#  'BJORNOYA ISLAND',
#  'KISTEFJELL',
#  'TROMSO/SKATTURA',
#  'OVERBYGD',
#  'TORSVAG FYR',
#  'FUGLOYKALVEN FYR',
#  'LYNGEN GJERDVASSBU',
#  'NORDNESFJELLET',
#  'SKIBOTIN',
#  'SKIBOTN 2',
#  'SKJERVOY',
#  'NORDREISA-OYENG',
#  'HASVIK-SLUSKFJELLET',
#  'ROGNSUNDET',
#  'LOPPA',
#  'HASVIK',
#  'HASVIK',
# ...

# %%
countries = [line[43:45].strip() for line in lines]

# %%
countries
# Out:
# ['',
#  'AF',
#  'AF',
#  '',
#  'AF',
#  'AF',
#  '',
#  '',
#  '',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'SV',
#  'SV',
#  'SV',
#  'SV',
#  'NO',
#  'SV',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  '',
#  '',
#  'NO',
#  'NO',
#  'NO',
# ...

# %%
states = [line[48:50].strip() for line in lines]

# %%
np.unique(states)
# Out:
# array(['', 'AK', 'AL', 'AR', 'AS', 'AZ', 'BC', 'CA', 'CO', 'CR', 'CT',
#        'DC', 'DE', 'FL', 'FM', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN',
#        'JQ', 'KS', 'KY', 'LA', 'MA', 'MB', 'MD', 'ME', 'MH', 'MI', 'MN',
#        'MO', 'MP', 'MS', 'MT', 'NB', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NS', 'NT', 'NU', 'NV', 'NY', 'OH', 'OK', 'ON', 'OR', 'PA', 'PC',
#        'PR', 'PW', 'QC', 'RI', 'SC', 'SD', 'TN', 'TX', 'UM', 'UT', 'VA',
#        'VI', 'VT', 'WA', 'WI', 'WV', 'WY', 'YK', 'YT'], dtype='<U2')

# %%
calls = [line[51:55].strip() for line in lines]

# %%
calls
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENRS',
#  'ENJA',
#  '',
#  'ENSO',
#  '',
#  '',
#  'ENFR',
#  '',
#  '',
#  'ENAS',
#  '',
#  '',
#  '',
#  '',
#  'ENSB',
#  '',
#  'ENAN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENDU',
#  'ENDR',
#  '',
#  'ENTC',
#  '',
#  '',
#  'ENBJ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENHK',
#  '',
#  '',
#  'ENSR',
#  'ENKA',
#  'ENAT',
#  '',
#  'ENHF',
#  '',
#  '',
#  '',
#  '',
#  'ENNA',
#  '',
#  '',
#  'ENHO',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENHV',
#  '',
#  'ENMH',
#  '',
#  '',
#  '',
#  '',
#  'ENBV',
#  '',
#  '',
#  'ENBS',
#  'ENHM',
#  'ENNE',
#  'ENQA',
#  'ENSE',
#  'ENQR',
#  'ENVD',
#  '',
#  'ENRO',
#  '',
#  'ENSN',
#  '',
#  'ENSL',
#  'ENQC',
#  'ENKR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENSS',
#  '',
#  '',
#  'ENHE',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENRS',
#  '',
#  '',
# ...

# %%
np.unique(calls)
# Out:
# array(['', '050E', '07MT', ..., 'ZYTL', 'ZYTX', 'ZYYY'], dtype='<U4')

# %%
lats = [line[57:64].strip() for line in lines]

# %%
lats
# Out:
# ['+00.000',
#  '+00.000',
#  '+00.000',
#  '+00.000',
#  '+32.950',
#  '+00.000',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+70.933',
#  '',
#  '+59.792',
#  '+61.383',
#  '+64.850',
#  '+59.980',
#  '+80.050',
#  '+77.000',
#  '+78.917',
#  '+78.067',
#  '+78.250',
#  '+78.917',
#  '+78.217',
#  '+78.246',
#  '+80.650',
#  '+69.293',
#  '+80.067',
#  '',
#  '+69.233',
#  '+69.600',
#  '+78.933',
#  '+77.683',
#  '+69.350',
#  '+77.517',
#  '+76.483',
#  '+69.056',
#  '+64.350',
#  '+78.650',
#  '+69.683',
#  '+69.650',
#  '+69.650',
#  '+74.517',
#  '+69.283',
#  '+69.700',
#  '+69.017',
#  '+70.250',
#  '+70.317',
#  '+69.567',
#  '+69.567',
#  '+69.367',
#  '+69.383',
#  '+70.033',
#  '+69.733',
#  '+70.600',
#  '+70.417',
#  '+70.333',
#  '+70.483',
#  '+70.487',
#  '+69.833',
#  '',
#  '+69.787',
#  '+69.017',
#  '+69.976',
#  '+69.583',
#  '+70.683',
#  '+70.683',
#  '+71.100',
#  '+69.367',
#  '+69.567',
#  '+70.069',
#  '+70.067',
#  '',
#  '+76.500',
#  '+70.450',
# ...

# %%
np.unique(lats)
# Out:
# array(['', '+00.000', '+00.017', ..., '-89.000', '-89.983', '-90.000'],
#       dtype='<U7')

# %%
lons = [line[65:73].strip() for line in lines]

# %%
lons
# Out:
# ['+000.000',
#  '+000.000',
#  '+000.000',
#  '+000.000',
#  '+065.567',
#  '+000.000',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-008.667',
#  '',
#  '+005.341',
#  '+005.867',
#  '+011.233',
#  '+002.250',
#  '+016.250',
#  '+015.500',
#  '+011.933',
#  '+013.633',
#  '+022.817',
#  '+011.933',
#  '+015.583',
#  '+015.466',
#  '+025.000',
#  '+016.144',
#  '+031.500',
#  '',
#  '+017.900',
#  '+017.833',
#  '+028.900',
#  '+014.783',
#  '+018.083',
#  '+020.817',
#  '+016.550',
#  '+018.540',
#  '+007.800',
#  '+016.367',
#  '+018.919',
#  '+018.933',
#  '+018.900',
#  '+019.017',
#  '+018.133',
#  '+019.017',
#  '+019.283',
#  '+019.500',
#  '+020.150',
#  '+020.100',
#  '+020.433',
#  '+020.267',
#  '+020.283',
#  '+020.983',
#  '+021.017',
#  '+022.450',
#  '+022.817',
#  '+021.467',
#  '+022.150',
#  '+022.140',
#  '+021.883',
#  '',
#  '+020.959',
#  '+023.067',
#  '+023.372',
#  '+023.533',
#  '+023.683',
#  '+023.683',
#  '+023.983',
#  '+024.433',
#  '+023.533',
# ...

# %%
elev = [line[74:81].strip() for line in lines]

# %%
elev
# Out:
# ['+7018.0',
#  '+7026.0',
#  '+7070.0',
#  '+0000.0',
#  '+1156.7',
#  '+8318.0',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+0009.0',
#  '',
#  '+0048.8',
#  '+0327.0',
#  '+0014.0',
#  '+0048.0',
#  '+0008.0',
#  '+0012.0',
#  '+0008.0',
#  '+0009.0',
#  '+0014.0',
#  '+0007.7',
#  '+0037.0',
#  '+0026.8',
#  '+0005.0',
#  '+0013.1',
#  '+0010.0',
#  '',
#  '+0009.0',
#  '+0014.0',
#  '+0020.0',
#  '+0006.0',
#  '+0012.0',
#  '+0020.0',
#  '+0010.0',
#  '+0076.8',
#  '+0000.0',
#  '+0020.0',
#  '+0009.4',
#  '+0114.5',
#  '+0020.0',
#  '+0018.0',
#  '+0982.0',
#  '+0014.0',
#  '+0078.0',
#  '+0024.0',
#  '+0038.0',
#  '+0710.0',
#  '+0710.0',
#  '+0005.0',
#  '+0020.0',
#  '+0015.0',
#  '+0005.0',
#  '+0438.0',
#  '+0010.0',
#  '+0011.0',
#  '+0007.0',
#  '+0006.4',
#  '+0006.0',
#  '',
#  '+0004.9',
#  '+0307.0',
#  '+0002.7',
#  '+0374.0',
#  '+0081.0',
#  '+0070.0',
#  '+0014.2',
#  '+0286.0',
#  '+0381.0',
#  '+0007.6',
#  '+0034.0',
#  '',
#  '+0010.0',
#  '+0006.0',
# ...

# %%
np.unique(elev)
# Out:
# array(['', '+0000.0', '+0000.1', ..., '-0388.0', '-0999.0', '-0999.9'],
#       dtype='<U7')

# %%
begin = [line[82:90] for line in lines]

# %%
np.unique(begin)
# Out:
# array(['19010101', '19060101', '19080101', ..., '20220330', '20220406',
#        '20220413'], dtype='<U8')

# %%
end = [line[91:99] for line in lines]

# %%
end
# Out:
# ['20130730',
#  '20170822',
#  '20150926',
#  '20120731',
#  '20120323',
#  '20100421',
#  '20160217',
#  '20160217',
#  '20200314',
#  '20160217',
#  '20041019',
#  '20220406',
#  '19880105',
#  '20220427',
#  '20081231',
#  '19910806',
#  '20050228',
#  '20220403',
#  '20220405',
#  '20140523',
#  '20041030',
#  '20220402',
#  '20220406',
#  '20050210',
#  '20220427',
#  '20220406',
#  '20220427',
#  '20220406',
#  '19751116',
#  '20140523',
#  '20220331',
#  '20220324',
#  '20220406',
#  '20070307',
#  '20140523',
#  '20220405',
#  '20220427',
#  '20220427',
#  '20220325',
#  '20220427',
#  '20220406',
#  '20220406',
#  '20220406',
#  '20220404',
#  '20150108',
#  '20140523',
#  '20220406',
#  '20140523',
#  '20220323',
#  '20220406',
#  '20050922',
#  '20220322',
#  '19780927',
#  '20140523',
#  '20220322',
#  '20220330',
#  '20070307',
#  '20081230',
#  '20220427',
#  '20220406',
#  '19750904',
#  '20220427',
#  '20220404',
#  '20220427',
#  '20140523',
#  '20220427',
# ...

# %%
usaf
# Out:
# ['007018',
#  '007026',
#  '007070',
#  '008260',
#  '008268',
#  '008307',
#  '008411',
#  '008414',
#  '008415',
#  '008418',
#  '010000',
#  '010010',
#  '010013',
#  '010014',
#  '010015',
#  '010016',
#  '010017',
#  '010020',
#  '010030',
#  '010040',
#  '010050',
#  '010060',
#  '010070',
#  '010071',
#  '010080',
#  '010090',
#  '010100',
#  '010110',
#  '010120',
#  '010140',
#  '010150',
#  '010160',
#  '010170',
#  '010171',
#  '010190',
#  '010200',
#  '010230',
#  '010231',
#  '010240',
#  '010250',
#  '010260',
#  '010270',
#  '010280',
#  '010300',
#  '010303',
#  '010320',
#  '010330',
#  '010340',
#  '010350',
#  '010360',
#  '010361',
#  '010370',
#  '010400',
#  '010410',
#  '010420',
#  '010430',
#  '010431',
#  '010435',
#  '010440',
#  '010450',
#  '010455',
#  '010460',
#  '010470',
#  '010490',
#  '010510',
#  '010520',
#  '010530',
#  '010550',
#  '010570',
#  '010580',
#  '010590',
#  '010610',
#  '010617',
#  '010620',
#  '010630',
#  '010650',
# ...

# %%
wban
# Out:
# ['99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
#  '99999',
# ...

# %%
stations
# Out:
# ['WXPOD 7018',
#  'WXPOD 7026',
#  'WXPOD 7070',
#  'WXPOD8270',
#  'WXPOD8278',
#  'WXPOD 8318',
#  'XM20',
#  'XM18',
#  'XM21',
#  'XM24',
#  'BOGUS NORWAY',
#  'JAN MAYEN(NOR-NAVY)',
#  'ROST',
#  'SORSTOKKEN',
#  'BRINGELAND',
#  'RORVIK/RYUM',
#  'FRIGG',
#  'VERLEGENHUKEN',
#  'HORNSUND',
#  'NY-ALESUND II',
#  'ISFJORD RADIO',
#  'EDGEOYA',
#  'NY-ALESUND',
#  'LONGYEARBYEN',
#  'LONGYEAR',
#  'KARL XII OYA',
#  'ANDOYA',
#  'KVITOYA',
#  '',
#  'SENJA-LAUKHELLA',
#  'HEKKINGEN FYR',
#  'KONGSOYA',
#  'AKSELOYA',
#  'GIBOSTAD',
#  'SVARTTANGEN',
#  'SORKAPPOYA',
#  'BARDUFOSS',
#  'DRAUGEN',
#  'PYRAMIDEN',
#  'TROMSO',
#  'TROMSO',
#  'TROMSO-HOLT',
#  'BJORNOYA ISLAND',
#  'KISTEFJELL',
#  'TROMSO/SKATTURA',
#  'OVERBYGD',
#  'TORSVAG FYR',
#  'FUGLOYKALVEN FYR',
#  'LYNGEN GJERDVASSBU',
#  'NORDNESFJELLET',
#  'SKIBOTIN',
#  'SKIBOTN 2',
#  'SKJERVOY',
#  'NORDREISA-OYENG',
#  'HASVIK-SLUSKFJELLET',
#  'ROGNSUNDET',
#  'LOPPA',
#  'HASVIK',
#  'HASVIK',
# ...

# %%
countries
# Out:
# ['',
#  'AF',
#  'AF',
#  '',
#  'AF',
#  'AF',
#  '',
#  '',
#  '',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'SV',
#  'SV',
#  'SV',
#  'SV',
#  'NO',
#  'SV',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'NO',
#  'SV',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '',
#  '',
#  '',
#  'NO',
#  'NO',
#  'NO',
# ...

# %%
states
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
calls
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENRS',
#  'ENJA',
#  '',
#  'ENSO',
#  '',
#  '',
#  'ENFR',
#  '',
#  '',
#  'ENAS',
#  '',
#  '',
#  '',
#  '',
#  'ENSB',
#  '',
#  'ENAN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENDU',
#  'ENDR',
#  '',
#  'ENTC',
#  '',
#  '',
#  'ENBJ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENHK',
#  '',
#  '',
#  'ENSR',
#  'ENKA',
#  'ENAT',
#  '',
#  'ENHF',
#  '',
#  '',
#  '',
#  '',
#  'ENNA',
#  '',
#  '',
#  'ENHO',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENHV',
#  '',
#  'ENMH',
#  '',
#  '',
#  '',
#  '',
#  'ENBV',
#  '',
#  '',
#  'ENBS',
#  'ENHM',
#  'ENNE',
#  'ENQA',
#  'ENSE',
#  'ENQR',
#  'ENVD',
#  '',
#  'ENRO',
#  '',
#  'ENSN',
#  '',
#  'ENSL',
#  'ENQC',
#  'ENKR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENSS',
#  '',
#  '',
#  'ENHE',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ENRS',
#  '',
#  '',
# ...

# %%
lats
# Out:
# ['+00.000',
#  '+00.000',
#  '+00.000',
#  '+00.000',
#  '+32.950',
#  '+00.000',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+70.933',
#  '',
#  '+59.792',
#  '+61.383',
#  '+64.850',
#  '+59.980',
#  '+80.050',
#  '+77.000',
#  '+78.917',
#  '+78.067',
#  '+78.250',
#  '+78.917',
#  '+78.217',
#  '+78.246',
#  '+80.650',
#  '+69.293',
#  '+80.067',
#  '',
#  '+69.233',
#  '+69.600',
#  '+78.933',
#  '+77.683',
#  '+69.350',
#  '+77.517',
#  '+76.483',
#  '+69.056',
#  '+64.350',
#  '+78.650',
#  '+69.683',
#  '+69.650',
#  '+69.650',
#  '+74.517',
#  '+69.283',
#  '+69.700',
#  '+69.017',
#  '+70.250',
#  '+70.317',
#  '+69.567',
#  '+69.567',
#  '+69.367',
#  '+69.383',
#  '+70.033',
#  '+69.733',
#  '+70.600',
#  '+70.417',
#  '+70.333',
#  '+70.483',
#  '+70.487',
#  '+69.833',
#  '',
#  '+69.787',
#  '+69.017',
#  '+69.976',
#  '+69.583',
#  '+70.683',
#  '+70.683',
#  '+71.100',
#  '+69.367',
#  '+69.567',
#  '+70.069',
#  '+70.067',
#  '',
#  '+76.500',
#  '+70.450',
# ...

# %%
lons
# Out:
# ['+000.000',
#  '+000.000',
#  '+000.000',
#  '+000.000',
#  '+065.567',
#  '+000.000',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-008.667',
#  '',
#  '+005.341',
#  '+005.867',
#  '+011.233',
#  '+002.250',
#  '+016.250',
#  '+015.500',
#  '+011.933',
#  '+013.633',
#  '+022.817',
#  '+011.933',
#  '+015.583',
#  '+015.466',
#  '+025.000',
#  '+016.144',
#  '+031.500',
#  '',
#  '+017.900',
#  '+017.833',
#  '+028.900',
#  '+014.783',
#  '+018.083',
#  '+020.817',
#  '+016.550',
#  '+018.540',
#  '+007.800',
#  '+016.367',
#  '+018.919',
#  '+018.933',
#  '+018.900',
#  '+019.017',
#  '+018.133',
#  '+019.017',
#  '+019.283',
#  '+019.500',
#  '+020.150',
#  '+020.100',
#  '+020.433',
#  '+020.267',
#  '+020.283',
#  '+020.983',
#  '+021.017',
#  '+022.450',
#  '+022.817',
#  '+021.467',
#  '+022.150',
#  '+022.140',
#  '+021.883',
#  '',
#  '+020.959',
#  '+023.067',
#  '+023.372',
#  '+023.533',
#  '+023.683',
#  '+023.683',
#  '+023.983',
#  '+024.433',
#  '+023.533',
# ...

# %%
elev
# Out:
# ['+7018.0',
#  '+7026.0',
#  '+7070.0',
#  '+0000.0',
#  '+1156.7',
#  '+8318.0',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+0009.0',
#  '',
#  '+0048.8',
#  '+0327.0',
#  '+0014.0',
#  '+0048.0',
#  '+0008.0',
#  '+0012.0',
#  '+0008.0',
#  '+0009.0',
#  '+0014.0',
#  '+0007.7',
#  '+0037.0',
#  '+0026.8',
#  '+0005.0',
#  '+0013.1',
#  '+0010.0',
#  '',
#  '+0009.0',
#  '+0014.0',
#  '+0020.0',
#  '+0006.0',
#  '+0012.0',
#  '+0020.0',
#  '+0010.0',
#  '+0076.8',
#  '+0000.0',
#  '+0020.0',
#  '+0009.4',
#  '+0114.5',
#  '+0020.0',
#  '+0018.0',
#  '+0982.0',
#  '+0014.0',
#  '+0078.0',
#  '+0024.0',
#  '+0038.0',
#  '+0710.0',
#  '+0710.0',
#  '+0005.0',
#  '+0020.0',
#  '+0015.0',
#  '+0005.0',
#  '+0438.0',
#  '+0010.0',
#  '+0011.0',
#  '+0007.0',
#  '+0006.4',
#  '+0006.0',
#  '',
#  '+0004.9',
#  '+0307.0',
#  '+0002.7',
#  '+0374.0',
#  '+0081.0',
#  '+0070.0',
#  '+0014.2',
#  '+0286.0',
#  '+0381.0',
#  '+0007.6',
#  '+0034.0',
#  '',
#  '+0010.0',
#  '+0006.0',
# ...

# %%
begin
# Out:
# ['20110309',
#  '20120713',
#  '20140923',
#  '20050101',
#  '20100519',
#  '20100421',
#  '20160217',
#  '20160216',
#  '20160217',
#  '20160217',
#  '20010927',
#  '19310101',
#  '19861120',
#  '19861120',
#  '19870117',
#  '19870116',
#  '19880320',
#  '19861109',
#  '19850601',
#  '19730101',
#  '19310103',
#  '19730101',
#  '19730106',
#  '20050210',
#  '19750929',
#  '19550101',
#  '19310103',
#  '19861118',
#  '19741130',
#  '19730101',
#  '19800314',
#  '19930501',
#  '19730101',
#  '20050216',
#  '20100825',
#  '20101008',
#  '19400713',
#  '20040510',
#  '19730101',
#  '19730101',
#  '19970201',
#  '20110928',
#  '19310103',
#  '19510101',
#  '20140522',
#  '19730101',
#  '19730101',
#  '19871202',
#  '19730101',
#  '20040510',
#  '20050916',
#  '19730101',
#  '19730101',
#  '19730101',
#  '20080917',
#  '19730101',
#  '20060207',
#  '19750515',
#  '20050102',
#  '19730101',
#  '19741117',
#  '19750905',
#  '19730101',
#  '19730101',
#  '19730102',
#  '19401008',
# ...

# %%
end
# Out:
# ['20130730',
#  '20170822',
#  '20150926',
#  '20120731',
#  '20120323',
#  '20100421',
#  '20160217',
#  '20160217',
#  '20200314',
#  '20160217',
#  '20041019',
#  '20220406',
#  '19880105',
#  '20220427',
#  '20081231',
#  '19910806',
#  '20050228',
#  '20220403',
#  '20220405',
#  '20140523',
#  '20041030',
#  '20220402',
#  '20220406',
#  '20050210',
#  '20220427',
#  '20220406',
#  '20220427',
#  '20220406',
#  '19751116',
#  '20140523',
#  '20220331',
#  '20220324',
#  '20220406',
#  '20070307',
#  '20140523',
#  '20220405',
#  '20220427',
#  '20220427',
#  '20220325',
#  '20220427',
#  '20220406',
#  '20220406',
#  '20220406',
#  '20220404',
#  '20150108',
#  '20140523',
#  '20220406',
#  '20140523',
#  '20220323',
#  '20220406',
#  '20050922',
#  '20220322',
#  '19780927',
#  '20140523',
#  '20220322',
#  '20220330',
#  '20070307',
#  '20081230',
#  '20220427',
#  '20220406',
#  '19750904',
#  '20220427',
#  '20220404',
#  '20220427',
#  '20140523',
#  '20220427',
# ...

# %%
pd.DataFrame(data = {
    'USAF': usaf,
    'WBAN': wban,
    'STATION NAME': stations,
    'CTRY': countries,
    'ST': states,
    'CALL': calls,
    'LAT': lats,
    'LON': lons,
    'ELEV(M)': elev,
    'BEGIN': begin,
    'END': end
}).to_csv('isd-history.csv', index = False)

# %%
history = pd.read_csv('isd-history.csv')

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
northeast = ['ME', 'NH', 'VT', 'MA', 'RI', 'CT', 'NY', 'PA', 'NJ']

# %%
south = ['MD', 'DE', 'VA', 'WV', 'DC', 'NC', 'SC', 'GA', 'FL', 'AL', 'MS', 'LA', 'TX', 'OK', 'AR', 'KY', 'TN']

# %%
midwest = ['OH', 'IN', 'MI', 'WI', 'IL', 'IA', 'MO', 'MN', 'KS', 'NE', 'ND', 'SD']

# %%
west = ['CA', 'OR', 'WA', 'AK', 'HI', 'ID', 'MT', 'WY', 'CO', 'UT', 'NV', 'AZ', 'NM']

# %%
len(northeast) + len(south) + len(midwest) + len(west)
# Out:
# 51

# %%
regdiv = {state: 'northeast' for state in northeast}

# %%
regdiv
# Out:
# {'ME': 'northeast',
#  'NH': 'northeast',
#  'VT': 'northeast',
#  'MA': 'northeast',
#  'RI': 'northeast',
#  'CT': 'northeast',
#  'NY': 'northeast',
#  'PA': 'northeast',
#  'NJ': 'northeast'}

# %%
regdiv.update({state: 'south' for state in south})

# %%
regdiv.update({state: 'midwest' for state in midwest})

# %%
regdiv.update({state: 'west' for state in west})

# %%
regdiv
# Out:
# {'ME': 'northeast',
#  'NH': 'northeast',
#  'VT': 'northeast',
#  'MA': 'northeast',
#  'RI': 'northeast',
#  'CT': 'northeast',
#  'NY': 'northeast',
#  'PA': 'northeast',
#  'NJ': 'northeast',
#  'MD': 'south',
#  'DE': 'south',
#  'VA': 'south',
#  'WV': 'south',
#  'DC': 'south',
#  'NC': 'south',
#  'SC': 'south',
#  'GA': 'south',
#  'FL': 'south',
#  'AL': 'south',
#  'MS': 'south',
#  'LA': 'south',
#  'TX': 'south',
#  'OK': 'south',
#  'AR': 'south',
#  'KY': 'south',
#  'TN': 'south',
#  'OH': 'midwest',
#  'IN': 'midwest',
#  'MI': 'midwest',
#  'WI': 'midwest',
#  'IL': 'midwest',
#  'IA': 'midwest',
#  'MO': 'midwest',
#  'MN': 'midwest',
#  'KS': 'midwest',
#  'NE': 'midwest',
#  'ND': 'midwest',
#  'SD': 'midwest',
#  'CA': 'west',
#  'OR': 'west',
#  'WA': 'west',
#  'AK': 'west',
#  'HI': 'west',
#  'ID': 'west',
#  'MT': 'west',
#  'WY': 'west',
#  'CO': 'west',
#  'UT': 'west',
#  'NV': 'west',
#  'AZ': 'west',
#  'NM': 'west'}

# %%
len(regdiv)
# Out:
# 51

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
history['region'] = history['ST'].apply(lambda state: regdiv[state] if state in regdiv else '')

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END   region
# ...

# %%
df = pd.read_csv('/Users/samerens/Downloads/weather_data.csv')

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
df['station_num'].unique()
# Out:
# array([ 10590, 700634, 714450, ..., 998215, 879360, 405690])

# %%
history['USAF'].unique()
# Out:
# array(['007018', '007026', '007070', ..., 'A07359', 'A51255', 'A51256'],
#       dtype=object)

# %%
count = 0
for station in stations:
    if station in usafs:
        count += 1

# %%
stations = df['station_num'].unique()

# %%
usafs = history['USAF'].unique()

# %%
count
# Out:
# 0

# %%
df.dtypes
# Out:
# station_num         int64
# temp_ft           float64
# year                int64
# month               int64
# day                 int64
# fog                 int64
# rain                int64
# snow                int64
# hail                int64
# thunder             int64
# tornado             int64
# precip_in         float64
# max_temp_frnht    float64
# min_temp_frnht    float64
# dtype: object

# %%
history.dtypes
# Out:
# USAF             object
# WBAN              int64
# STATION NAME     object
# CTRY             object
# ST               object
# CALL             object
# LAT             float64
# LON             float64
# ELEV(M)         float64
# BEGIN             int64
# END               int64
# region           object
# dtype: object

# %%
df['station_num']
# Out:
# 0            10590
# 1            10590
# 2            10590
# 3            10590
# 4            10590
#              ...
# 42531152    350850
# 42531153    350850
# 42531154    350850
# 42531155    350850
# 42531156    350850
# Name: station_num, Length: 42531157, dtype: int64

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END   region
# ...
