# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'doc.pdf',
#  'Untitled.ipynb',
#  'doc.tex',
#  'code',
#  'GSOD_DESC.txt',
#  'doc.out',
#  'README.md',
#  '.gitignore',
#  'gsod-analysis-part-2.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  'data',
#  'doc.aux',
#  'gsod-analysis-part-1.ipynb',
#  'doc.log']

# %%
os.listdir('data')
# Out:
# ['1975_dir',
#  '.DS_Store',
#  '2004_dir',
#  '2005_dir',
#  '2007_dir',
#  '2006_dir',
#  '2002_dir',
#  '2003_dir',
#  '2001_dir',
#  '2000_dir',
#  '1975_dir.zip',
#  '2008_dir']

# %%
os.listdir('data/1975_dir')
# Out:
# ['1975weatherdata.csv', '1975stations.txt']

# %%
df = pd.read_csv('data/1975_dir/1975weatherdata.csv')

# %%
df
# Out:
#          Unnamed: 0  station_num  year  month  day     WBAN  temp_ft  \
# 0                 0       722210  1975      1    1  13858.0     66.2
# 1                 1       722210  1975      1    2  13858.0     54.1
# 2                 2       722210  1975      1    3  13858.0      0.0
# 3                 3       722210  1975      1    4  13858.0     54.6
# 4                 4       722210  1975      1    5  13858.0     43.2
# ...             ...          ...   ...    ...  ...      ...      ...
# 1349522         347       105260  1975     12   27      NaN     36.6
# 1349523         348       105260  1975     12   28      NaN     30.8
# 1349524         349       105260  1975     12   29      NaN     28.6
# 1349525         350       105260  1975     12   30      NaN      0.0
# 1349526         351       105260  1975     12   31      NaN     31.5
#
#          dewpt_ft  slp_mb  STP  ...  rain  snow  hail  thunder  tornado  \
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#          station_num  year  month  day     WBAN  temp_ft  dewpt_ft  slp_mb  \
# 0             722210  1975      1    1  13858.0     66.2      62.7  1023.0
# 1             722210  1975      1    2  13858.0     54.1      37.6  1025.2
# 2             722210  1975      1    3  13858.0      0.0      48.7  1021.6
# 3             722210  1975      1    4  13858.0     54.6      52.3  1018.0
# 4             722210  1975      1    5  13858.0     43.2      34.3  1024.0
# ...              ...   ...    ...  ...      ...      ...       ...     ...
# 1349522       105260  1975     12   27      NaN     36.6      36.6  1030.2
# 1349523       105260  1975     12   28      NaN     30.8      30.8  1027.8
# 1349524       105260  1975     12   29      NaN     28.6      28.6     0.0
# 1349525       105260  1975     12   30      NaN      0.0       0.0  1025.7
# 1349526       105260  1975     12   31      NaN     31.5      31.5  1020.5
#
#          STP  visib_mi  ...  rain  snow  hail  thunder  tornado  \
# ...

# %%
df.columns[df.isna().sum() > 0]
# Out:
# Index(['WBAN', 'temp_ft', 'dewpt_ft', 'slp_mb', 'STP', 'visib_mi', 'wind_knt',
#        'maxwind_knt', 'GUST', 'precip_flag', 'SNDP'],
#       dtype='object')

# %%
df.drop(['WBAN', 'STP', 'GUST', 'SNDP', 'precip_flag', 'slp_mb'], axis = 1).isna().sum().sum() / df.size
# Out:
# 0.0003255770355094785

# %%
df.isna().sum().sum() / df.size
# Out:
# 0.14211516331277552

# %%
df2 = df.drop(df.columns[df.isna().sum() > 0], axis = 1)

# %%
df2
# Out:
#          station_num  year  month  day  fog  rain  snow  hail  thunder  \
# 0             722210  1975      1    1    1     0     0     0        0
# 1             722210  1975      1    2    0     0     0     0        0
# 2             722210  1975      1    3    1     0     0     0        0
# 3             722210  1975      1    4    1     0     0     0        0
# 4             722210  1975      1    5    0     0     0     0        0
# ...              ...   ...    ...  ...  ...   ...   ...   ...      ...
# 1349522       105260  1975     12   27    1     1     0     0        0
# 1349523       105260  1975     12   28    1     0     0     0        0
# 1349524       105260  1975     12   29    1     0     0     0        0
# 1349525       105260  1975     12   30    1     0     0     0        0
# 1349526       105260  1975     12   31    1     0     0     0        0
#
#          tornado  max_temp_frnht  min_temp_frnht  precip_in
# ...

# %%
df2.isna().sum()
# Out:
# station_num       0
# year              0
# month             0
# day               0
# fog               0
# rain              0
# snow              0
# hail              0
# thunder           0
# tornado           0
# max_temp_frnht    0
# min_temp_frnht    0
# precip_in         0
# dtype: int64

# %%
import sklearn

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
train_df, test_df = train_test_split(df2)

# %%
train_df
# Out:
#         station_num  year  month  day  fog  rain  snow  hail  thunder  \
# 943150       722610  1975      5   13    1     0     0     1        0
# 858284       725570  1975      2   19    0     0     0     0        0
# 994232       401800  1975     11   17    0     0     0     0        0
# 562365       163200  1975      1    9    0     0     0     0        0
# 179918       727530  1975      8   29    0     0     0     0        0
# ...             ...   ...    ...  ...  ...   ...   ...   ...      ...
# 317044       838400  1975      8   24    0     0     0     0        0
# 231385       442660  1975      7    6    0     0     0     0        0
# 409827       306350  1975      1   10    1     0     0     0        0
# 247177       725628  1975     12    1    0     0     0     0        0
# 252889       370260  1975      4    2    0     0     0     0        0
#
#         tornado  max_temp_frnht  min_temp_frnht  precip_in
# 943150        0             0.0             0.0       0.00
# ...

# %%
test_df
# Out:
#          station_num  year  month  day  fog  rain  snow  hail  thunder  \
# 657341        726520  1975      7    5    0     0     0     0        0
# 918090        842550  1975      5    2    0     0     0     0        0
# 158807        723140  1975      6    4    0     0     0     0        0
# 1139064       741210  1975      7   15    1     0     0     0        0
# 101299        728710  1975      6    2    0     0     0     0        0
# ...              ...   ...    ...  ...  ...   ...   ...   ...      ...
# 437272        372350  1975      3   24    1     0     0     0        0
# 1103644       688160  1975      8   28    0     0     0     0        0
# 1223872       471080  1975      7   14    1     0     0     0        0
# 396276        247240  1975      7    4    1     0     0     0        0
# 176546        103050  1975      9    1    1     0     0     0        0
#
#          tornado  max_temp_frnht  min_temp_frnht  precip_in
# ...

# %%
train_y = pd.DataFrame(train_df['tornado'])

# %%
test_y = pd.DataFrame(test_df['tornado'])

# %%
train_x = train_df.drop('tornado', axis = 1)
test_x = test_df.drop('tornado', axis = 1)

# %%
train_y
# Out:
#         tornado
# 943150        0
# 858284        0
# 994232        0
# 562365        0
# 179918        0
# ...         ...
# 317044        0
# 231385        0
# 409827        0
# 247177        0
# 252889        0
#
# [1012145 rows x 1 columns]

# %%
sum(train_y['tornado'])
# Out:
# 31

# %%
sum(test_y['tornado'])
# Out:
# 5

# %%
model.fit(train_x, train_y)
# Out:
# /Users/samerens/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
import warnings

# %%
warnings.filterwarnings(action = 'ignore')

# %%
predict = model.predict(test_x)

# %%
sum(predict)
# Out:
# 0

# %%
predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import numpy as np

# %%
model.accuracy_score()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_15253/3919812661.py in <module>
# ----> 1 model.accuracy_score()
#
# AttributeError: 'LogisticRegression' object has no attribute 'accuracy_score'

# %%
sklearn.accuracy_score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_15253/1844001841.py in <module>
# ----> 1 sklearn.accuracy_score
#
# AttributeError: module 'sklearn' has no attribute 'accuracy_score'

# %%
help(sklearn.metrics.accuracy_score)
# Out:
# Help on function accuracy_score in module sklearn.metrics._classification:
#
# accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)
#     Accuracy classification score.
#
#     In multilabel classification, this function computes subset accuracy:
#     the set of labels predicted for a sample must *exactly* match the
#     corresponding set of labels in y_true.
#
#     Read more in the :ref:`User Guide <accuracy_score>`.
#
#     Parameters
#     ----------
#     y_true : 1d array-like, or label indicator array / sparse matrix
#         Ground truth (correct) labels.
#
#     y_pred : 1d array-like, or label indicator array / sparse matrix
#         Predicted labels, as returned by a classifier.
#
#     normalize : bool, default=True
#         If ``False``, return the number of correctly classified samples.
#         Otherwise, return the fraction of correctly classified samples.
#
#     sample_weight : array-like of shape (n_samples,), default=None
# ...

# %%
sklearn.metrics.accuracy_score(y_true = test_y, y_pred = predict)
# Out:
# 0.9999851800036753
