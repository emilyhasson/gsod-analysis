# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['Untitled1.ipynb',
#  '.DS_Store',
#  'isd-history.txt',
#  'data_cleaning.ipynb',
#  'Untitled3.ipynb',
#  'Untitled.ipynb',
#  'Untitled2.ipynb',
#  'gzip_pal.py',
#  'isd-history.csv',
#  'data_agg.py',
#  'gsod-analysis-part-2.ipynb',
#  '.ipynb_checkpoints',
#  'country-list.txt',
#  'gsod-analysis-part-1.ipynb']

# %%
history = pd.read_csv('isd-history.csv')

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
df = pd.read_csv('/Users/samerens/Downloads/weather_data.csv')

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
df.dtypes
# Out:
# station_num         int64
# temp_ft           float64
# year                int64
# month               int64
# day                 int64
# fog                 int64
# rain                int64
# snow                int64
# hail                int64
# thunder             int64
# tornado             int64
# precip_in         float64
# max_temp_frnht    float64
# min_temp_frnht    float64
# dtype: object

# %%
df['station_num']
# Out:
# 0            10590
# 1            10590
# 2            10590
# 3            10590
# 4            10590
#              ...
# 42531152    350850
# 42531153    350850
# 42531154    350850
# 42531155    350850
# 42531156    350850
# Name: station_num, Length: 42531157, dtype: int64

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
history.dtypes
# Out:
# USAF             object
# WBAN              int64
# STATION NAME     object
# CTRY             object
# ST               object
# CALL             object
# LAT             float64
# LON             float64
# ELEV(M)         float64
# BEGIN             int64
# END               int64
# dtype: object

# %%
history['USAF']
# Out:
# 0        007018
# 1        007026
# 2        007070
# 3        008260
# 4        008268
#           ...
# 29605    A07355
# 29606    A07357
# 29607    A07359
# 29608    A51255
# 29609    A51256
# Name: USAF, Length: 29610, dtype: object

# %%
history['USAF'].unique()
# Out:
# array(['007018', '007026', '007070', ..., 'A07359', 'A51255', 'A51256'],
#       dtype=object)

# %%
stations = history['USAF'].apply(lambda code: code.strip('A')).apply(int)

# %%
count = 0
for station in stations:
    if station in df['station_num']:
        count += 1

# %%
count
# Out:
# 29610

# %%
len(history)
# Out:
# 29610

# %%
len(df['station_num'].unique())
# Out:
# 15491

# %%
northeast = ['ME', 'NH', 'VT', 'MA', 'RI', 'CT', 'NY', 'PA', 'NJ']

# %%
south = ['FL', 'GA', 'AL', 'MS', 'LA', 'AR', 'TX', 'OK', 'TN', 'KY', 'WV', 'VA', 'MD', 'DE', 'DC', 'NC', 'SC']

# %%
midwest = ['OH', 'IN', 'MI', 'WI', 'MN', 'ND', 'SD', 'NE', 'KS', 'MO', 'IA', 'IL']

# %%
west = ['CA', 'OR', 'WA', 'UT', 'CO', 'WY', 'ID', 'MT', 'NV', 'AZ', 'NM', 'AK', 'HI']

# %%
len(northeast) + len(south) + len(midwest) + len(west)
# Out:
# 51

# %%
regdiv = {state: 'northeast' for state in northeast}

# %%
regdiv.update({state: 'south' for state in south})

# %%
regdiv.update({state: 'midwest' for state in midwest})

# %%
regdiv.update({state: 'west' for state in west})

# %%
regdiv
# Out:
# {'ME': 'northeast',
#  'NH': 'northeast',
#  'VT': 'northeast',
#  'MA': 'northeast',
#  'RI': 'northeast',
#  'CT': 'northeast',
#  'NY': 'northeast',
#  'PA': 'northeast',
#  'NJ': 'northeast',
#  'FL': 'south',
#  'GA': 'south',
#  'AL': 'south',
#  'MS': 'south',
#  'LA': 'south',
#  'AR': 'south',
#  'TX': 'south',
#  'OK': 'south',
#  'TN': 'south',
#  'KY': 'south',
#  'WV': 'south',
#  'VA': 'south',
#  'MD': 'south',
#  'DE': 'south',
#  'DC': 'south',
#  'NC': 'south',
#  'SC': 'south',
#  'OH': 'midwest',
#  'IN': 'midwest',
#  'MI': 'midwest',
#  'WI': 'midwest',
#  'MN': 'midwest',
#  'ND': 'midwest',
#  'SD': 'midwest',
#  'NE': 'midwest',
#  'KS': 'midwest',
#  'MO': 'midwest',
#  'IA': 'midwest',
#  'IL': 'midwest',
#  'CA': 'west',
#  'OR': 'west',
#  'WA': 'west',
#  'UT': 'west',
#  'CO': 'west',
#  'WY': 'west',
#  'ID': 'west',
#  'MT': 'west',
#  'NV': 'west',
#  'AZ': 'west',
#  'NM': 'west',
#  'AK': 'west',
#  'HI': 'west'}

# %%
states = northeast + midwest + south + west

# %%
us_history = history[(history['CTRY'] == 'US') & (history['ST'] == history['ST'])]

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END
# ...

# %%
us_history['ST'].unique()
# Out:
# array(['NM', 'CA', 'FL', 'MI', 'NV', 'TX', 'NC', 'WA', 'AZ', 'OR', 'AR',
#        'AL', 'MD', 'UT', 'KY', 'IN', 'GA', 'AK', 'MS', 'VA', 'CO', 'SD',
#        'LA', 'SC', 'MT', 'IL', 'WV', 'TN', 'MO', 'OK', 'MN', 'IA', 'PA',
#        'NE', 'ID', 'WI', 'WY', 'OH', 'NJ', 'KS', 'ME', 'ND', 'VT', 'CT',
#        'NY', 'RI', 'MA', 'DE', 'NH', 'HI', 'PR', 'VI', 'DC'], dtype=object)

# %%
us_history = us_history[(us_history['ST'] != 'PR') & (us_history['ST'] != 'VI')]

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END
# ...

# %%
us_history['ST'].unique()
# Out:
# array(['NM', 'CA', 'FL', 'MI', 'NV', 'TX', 'NC', 'WA', 'AZ', 'OR', 'AR',
#        'AL', 'MD', 'UT', 'KY', 'IN', 'GA', 'AK', 'MS', 'VA', 'CO', 'SD',
#        'LA', 'SC', 'MT', 'IL', 'WV', 'TN', 'MO', 'OK', 'MN', 'IA', 'PA',
#        'NE', 'ID', 'WI', 'WY', 'OH', 'NJ', 'KS', 'ME', 'ND', 'VT', 'CT',
#        'NY', 'RI', 'MA', 'DE', 'NH', 'HI', 'DC'], dtype=object)

# %%
len(us_history['ST'].unique())
# Out:
# 51

# %%
region = regdiv

# %%
region
# Out:
# {'ME': 'northeast',
#  'NH': 'northeast',
#  'VT': 'northeast',
#  'MA': 'northeast',
#  'RI': 'northeast',
#  'CT': 'northeast',
#  'NY': 'northeast',
#  'PA': 'northeast',
#  'NJ': 'northeast',
#  'FL': 'south',
#  'GA': 'south',
#  'AL': 'south',
#  'MS': 'south',
#  'LA': 'south',
#  'AR': 'south',
#  'TX': 'south',
#  'OK': 'south',
#  'TN': 'south',
#  'KY': 'south',
#  'WV': 'south',
#  'VA': 'south',
#  'MD': 'south',
#  'DE': 'south',
#  'DC': 'south',
#  'NC': 'south',
#  'SC': 'south',
#  'OH': 'midwest',
#  'IN': 'midwest',
#  'MI': 'midwest',
#  'WI': 'midwest',
#  'MN': 'midwest',
#  'ND': 'midwest',
#  'SD': 'midwest',
#  'NE': 'midwest',
#  'KS': 'midwest',
#  'MO': 'midwest',
#  'IA': 'midwest',
#  'IL': 'midwest',
#  'CA': 'west',
#  'OR': 'west',
#  'WA': 'west',
#  'UT': 'west',
#  'CO': 'west',
#  'WY': 'west',
#  'ID': 'west',
#  'MT': 'west',
#  'NV': 'west',
#  'AZ': 'west',
#  'NM': 'west',
#  'AK': 'west',
#  'HI': 'west'}

# %%
us_history['region'] = us_history['ST'].apply(lambda state: region[state])
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/1926718426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_history['region'] = us_history['ST'].apply(lambda state: region[state])

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END   region
# ...

# %%
stations_to_regions = dict(zip(us_history['USAF'], us_history['region']))

# %%
stations_to_regions
# Out:
# {690014: 'west',
#  690020: 'west',
#  690070: 'west',
#  690090: 'south',
#  690110: 'midwest',
#  690140: 'west',
#  690150: 'west',
#  690170: 'west',
#  690174: 'west',
#  690190: 'south',
#  690200: 'south',
#  690210: 'south',
#  690220: 'south',
#  690230: 'west',
#  690240: 'west',
#  690250: 'south',
#  690260: 'midwest',
#  690280: 'south',
#  690290: 'south',
#  690310: 'west',
#  690320: 'west',
#  690330: 'west',
#  690500: 'south',
#  690524: 'south',
#  690584: 'west',
#  691164: 'south',
#  691174: 'south',
#  691224: 'west',
#  691324: 'south',
#  691334: 'west',
#  691414: 'west',
#  691484: 'west',
#  691804: 'south',
#  692364: 'west',
#  692494: 'west',
#  692534: 'south',
#  692584: 'west',
#  692644: 'midwest',
#  692694: 'west',
#  692704: 'south',
#  692754: 'south',
#  692764: 'south',
#  692784: 'west',
#  693254: 'south',
#  693654: 'west',
#  694300: 'west',
#  694604: 'west',
#  695354: 'south',
#  695364: 'south',
#  695414: 'west',
#  695424: 'west',
# ...

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END   region
# ...

# %%
us_history['USAF'] = us_history['USAF'].apply(lambda station: station.strip('A')).apply(int)
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/707842999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_history['USAF'] = us_history['USAF'].apply(lambda station: station.strip('A')).apply(int)

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END   region
# ...

# %%
stations_to_regions
# Out:
# {690014: 'west',
#  690020: 'west',
#  690070: 'west',
#  690090: 'south',
#  690110: 'midwest',
#  690140: 'west',
#  690150: 'west',
#  690170: 'west',
#  690174: 'west',
#  690190: 'south',
#  690200: 'south',
#  690210: 'south',
#  690220: 'south',
#  690230: 'west',
#  690240: 'west',
#  690250: 'south',
#  690260: 'midwest',
#  690280: 'south',
#  690290: 'south',
#  690310: 'west',
#  690320: 'west',
#  690330: 'west',
#  690500: 'south',
#  690524: 'south',
#  690584: 'west',
#  691164: 'south',
#  691174: 'south',
#  691224: 'west',
#  691324: 'south',
#  691334: 'west',
#  691414: 'west',
#  691484: 'west',
#  691804: 'south',
#  692364: 'west',
#  692494: 'west',
#  692534: 'south',
#  692584: 'west',
#  692644: 'midwest',
#  692694: 'west',
#  692704: 'south',
#  692754: 'south',
#  692764: 'south',
#  692784: 'west',
#  693254: 'south',
#  693654: 'west',
#  694300: 'west',
#  694604: 'west',
#  695354: 'south',
#  695364: 'south',
#  695414: 'west',
#  695424: 'west',
# ...

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
df['region'] = df['station_num'].apply(lambda station: stations_to_regions[station] if station in stations_to_regions else '')

# %%
df['station_num'].unique()
# Out:
# array([ 10590, 700634, 714450, ..., 998215, 879360, 405690])

# %%
us_history['USAF'].unique()
# Out:
# array([690014, 690020, 690070, ...,   7359,  51255,  51256])

# %%
df2 = df[df['station_num'] != 10590]

# %%
df2
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
len(df['station_num'].unique())
# Out:
# 15491

# %%
len(stations_to_regions)
# Out:
# 3784

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
df['region'].unique()
# Out:
# array(['', 'west', 'midwest', 'south', 'northeast'], dtype=object)

# %%
df2 = df[df['region'] != '']

# %%
df2
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527773       726558     30.5  2008     12   27    1     0     1     0
# 42527774       726558     11.7  2008     12   28    1     0     0     0
# 42527775       726558     15.6  2008     12   29    1     0     0     0
# 42527776       726558      6.0  2008     12   30    1     0     0     0
# 42527777       726558     -5.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht   region
# ...

# %%
west_df = df[df['region'] == 'west']

# %%
midwest_df = df[df['region'] == 'midwest']

# %%
northeast_df = df[df['region'] == 'northeast']

# %%
south_df = df[df['region'] == 'south']

# %%
northeast_df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 14704          744104     33.7  2004      1    1    0     0     0     0
# 14705          744104     35.5  2004      1    3    1     0     0     0
# 14706          744104     38.9  2004      1    4    1     0     0     0
# 14707          744104     25.5  2004      1    6    1     1     0     0
# 14708          744104     12.5  2004      1    7    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42526484       725156     38.2  2008     12   27    1     0     0     1
# 42526485       725156     44.3  2008     12   28    1     1     0     0
# 42526486       725156     35.7  2008     12   29    0     0     0     0
# 42526487       725156     32.6  2008     12   30    1     1     0     0
# 42526488       725156     22.7  2008     12   31    1     0     1     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht  \
# ...

# %%
midwest_df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 1947           724303     33.6  2004      1    1    0     0     0     0
# 1948           724303     45.6  2004      1    2    1     0     0     0
# 1949           724303     55.3  2004      1    3    1     0     0     0
# 1950           724303     38.4  2004      1    4    1     0     0     0
# 1951           724303     32.6  2004      1    5    1     1     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527773       726558     30.5  2008     12   27    1     0     1     0
# 42527774       726558     11.7  2008     12   28    1     0     0     0
# 42527775       726558     15.6  2008     12   29    1     0     0     0
# 42527776       726558      6.0  2008     12   30    1     0     0     0
# 42527777       726558     -5.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht   region
# ...

# %%
south_df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 3600           723525     55.0  2004      1    1    0     0     0     0
# 3601           723525     56.6  2004      1    2    0     0     0     0
# 3602           723525     54.5  2004      1    3    0     0     0     0
# 3603           723525     37.1  2004      1    4    0     0     0     0
# 3604           723525     24.0  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42519741       722469     68.2  2008     12   27    1     0     0     0
# 42519742       722469     44.0  2008     12   28    0     0     0     0
# 42519743       722469     45.3  2008     12   29    0     0     0     0
# 42519744       722469     50.9  2008     12   30    0     0     0     0
# 42519745       722469     50.6  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
west_df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527438       994670     25.9  2008     12   27    0     0     0     0
# 42527439       994670     20.0  2008     12   28    0     0     0     0
# 42527440       994670     15.6  2008     12   29    0     0     0     0
# 42527441       994670     14.0  2008     12   30    0     0     0     0
# 42527442       994670     13.3  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
len(northeast_df)
# Out:
# 785177

# %%
len(west_df)
# Out:
# 2545086

# %%
len(south_df)
# Out:
# 2995866

# %%
len(midwest_df)
# Out:
# 2416682

# %%
sum(northeast_df['tornado'])
# Out:
# 5

# %%
sum(west_df['tornado'])
# Out:
# 38

# %%
sum(south_df['tornado'])
# Out:
# 127

# %%
sum(midwest_df['tornado'])
# Out:
# 27

# %%
max(midwest_df['year'])
# Out:
# 2019

# %%
max(south_df['year'])
# Out:
# 2019

# %%
max(northeast_df['year'])
# Out:
# 2019

# %%
max(west_df['year'])
# Out:
# 2019

# %%
west = west_df.groupby(['station_num', 'year']).agg({
    'temp_ft': np.mean,
    'fog': np.sum,
    'rain': np.sum,
    'snow': np.sum,
    'hail': np.sum,
    'thunder': np.sum,
    'tornado': np.sum,
    'precip_in': np.sum,
    'max_temp_frnht': np.max,
    'min_temp_frnht': np.min
}).reset_index()

# %%
import numpy as np

# %%
northeast
# Out:
#       station_num  year    temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 0          720304  2004  59.808163    0     0     0     0        0        0
# 1          720304  2008  52.549401    0     0     0     0        0        0
# 2          720304  2009  53.038643    0     0     0     0        0        0
# 3          720304  2010  55.861631    0     0     0     0        0        0
# 4          720304  2011  55.609091    0     0     0     0        0        0
# ...           ...   ...        ...  ...   ...   ...   ...      ...      ...
# 2586       998267  2010  49.488720    0     0     0     0        0        0
# 2587       998342  2010  57.841066    0     0     0     0        0        0
# 2588       998428  2010  32.595238    0     0     0     0        0        0
# 2589       998435  2018  28.189000    0     0     0     0        0        0
# 2590       998442  2018  30.773786    0     0     0     0        0        0
#
#       precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
midwest
# Out:
#       station_num  year    temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 0          711680  2000  44.126772    0     0     0     0        0        0
# 1          711680  2002  34.439073    0     0     0     0        0        0
# 2          711680  2003   5.271429    0     0     0     0        0        0
# 3          711680  2008  29.298611    0     0     0     0        0        0
# 4          711680  2009  47.992193    0     0     0     0        0        0
# ...           ...   ...        ...  ...   ...   ...   ...      ...      ...
# 7983       998405  2018  28.920619    0     0     0     0        0        0
# 7984       998407  2010  56.106250    0     0     0     0        0        0
# 7985       998407  2018  34.004286    0     0     0     0        0        0
# 7986       998497  2018  31.039252    0     0     0     0        0        0
# 7987       998499  2018  31.753398    0     0     0     0        0        0
#
#       precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
south
# Out:
#        station_num  year    temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 0           690190  2000  67.770930   63     7     2    21        1        0
# 1           690190  2002  64.788396   72    10     3    19        2        0
# 2           690190  2003  70.764831   55     1     1    27        0        0
# 3           690190  2004  65.097744   84     8     3    32        3        0
# 4           690190  2008  64.607485   80    15     4    18        8        0
# ...            ...   ...        ...  ...   ...   ...   ...      ...      ...
# 10290       998485  2018  55.134146    0     0     0     0        0        0
# 10291       998486  2018  60.737255    0     0     0     0        0        0
# 10292       998487  2018  60.408421    0     0     0     0        0        0
# 10293       998490  2018  58.396040    0     0     0     0        0        0
# 10294       998491  2018  60.831633    0     0     0     0        0        0
#
# ...

# %%
west
# Out:
#       station_num  year    temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 0          690150  2000  68.191346   19     0     0     6        0        0
# 1          690150  2002  67.863030   26     0     0     9        0        0
# 2          690150  2003  70.209898   29     1     0     8        0        0
# 3          690150  2004  69.581518   33     2     0     5        0        0
# 4          690150  2008  69.414679   29     1     0    17        0        0
# ...           ...   ...        ...  ...   ...   ...   ...      ...      ...
# 8744       999999  2015  60.502795    0     0     0     0        0        0
# 8745       999999  2016  64.506811    0     0     0     0        0        0
# 8746       999999  2017  55.360366    0     0     0     0        0        0
# 8747       999999  2018  46.184356  185    33     1     8        0        0
# 8748       999999  2019  31.235714    0     0     0     0        0        0
#
#       precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
south['tornado'].unique()
# Out:
# array([0, 1, 8, 3, 2, 5, 4])

# %%
south[south['tornado'] == 8]
# Out:
#       station_num  year  temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 2075       722010  2000     77.6  146    38     1    49       36        8
#
#       precip_in  max_temp_frnht  min_temp_frnht
# 2075       33.2            93.0             0.0

# %%
history[history['USAF'] == '722010']
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 17848  722010  12836  KEY WEST INTERNATIONAL AIRPOR   US  FL  KEYW  24.557
#
#           LON  ELEV(M)     BEGIN       END
# 17848 -81.755      0.3  19730101  20220428

# %%
np.unique(list(df[(df['station_num'] == 722010) & (df['year'] == 2000)]['tornado']))
# Out:
# array([0, 1])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(south['year'], south['tornado'])

# %%
south.dtypes
# Out:
# station_num         int64
# year                int64
# temp_ft           float64
# fog                 int64
# rain                int64
# snow                int64
# hail                int64
# thunder             int64
# tornado             int64
# precip_in         float64
# max_temp_frnht    float64
# min_temp_frnht    float64
# dtype: object

# %%
sample_df = south[south['station_num'] == 722010]

# %%
sample_df
# Out:
#       station_num  year    temp_ft  fog  rain  snow  hail  thunder  tornado  \
# 2075       722010  2000  77.600000  146    38     1    49       36        8
# 2076       722010  2002  78.459403  142    46     0    22       35        3
# 2077       722010  2003  78.469096  144    37     0    29       18        1
# 2078       722010  2004  77.523894  141    34     0    22       21        0
# 2079       722010  2008  78.115476  114     8     0    32       10        2
# 2080       722010  2009  78.430655  124     8     0    38       13        0
# 2081       722010  2010  76.221739  135    10     0    25        8        0
# 2082       722010  2011  78.528107  112     2     0    25        0        0
# 2083       722010  2012  77.650000  119     5     0    15        2        0
# 2084       722010  2013  78.547024  120    10     0    14        5        0
# 2085       722010  2015  79.877681  126     8     0    46        5        0
# ...

# %%
len(sample_df)
# Out:
# 13

# %%
df[(df['year'] == 2014) & (df['station_num'] == 722010)]
# Out:
# Empty DataFrame
# Columns: [station_num, temp_ft, year, month, day, fog, rain, snow, hail, thunder, tornado, precip_in, max_temp_frnht, min_temp_frnht, region]
# Index: []

# %%
train_df = sample_df[sample_df['year'] < 2014]

# %%
test_df = sample_df[sample_df['year'] > 2014]

# %%
len(train_df)
# Out:
# 10

# %%
len(test_df)
# Out:
# 3

# %%
3 / 13
# Out:
# 0.23076923076923078

# %%
10 / 13
# Out:
# 0.7692307692307693

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
mlr = LinearRegression()

# %%
train_x = train_df.drop('tornado', axis = 1)

# %%
train_y = train_df['tornado']

# %%
test_x = test_df.drop('tornado', axis = 1)

# %%
test_y = test_df['tornado']

# %%
mlr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
predict = mlr.predict(test_x)

# %%
predict
# Out:
# array([-1.26709795, -0.87891335, -3.41464825])

# %%
accuracy_score(y_true = test_y, y_pred = predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [179], in <cell line: 1>()
# ----> 1 accuracy_score(y_true = test_y, y_pred = predict)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# ...

# %%
help(accuracy_score)
# Out:
# Help on function accuracy_score in module sklearn.metrics._classification:
#
# accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)
#     Accuracy classification score.
#
#     In multilabel classification, this function computes subset accuracy:
#     the set of labels predicted for a sample must *exactly* match the
#     corresponding set of labels in y_true.
#
#     Read more in the :ref:`User Guide <accuracy_score>`.
#
#     Parameters
#     ----------
#     y_true : 1d array-like, or label indicator array / sparse matrix
#         Ground truth (correct) labels.
#
#     y_pred : 1d array-like, or label indicator array / sparse matrix
#         Predicted labels, as returned by a classifier.
#
#     normalize : bool, default=True
#         If ``False``, return the number of correctly classified samples.
#         Otherwise, return the fraction of correctly classified samples.
#
#     sample_weight : array-like of shape (n_samples,), default=None
# ...

# %%
sum(abs(test_y - predict))
# Out:
# 5.560659551075105

# %%
list(test_y)
# Out:
# [0, 0, 0]

# %%
list(predict)
# Out:
# [-1.2670979544410557, -0.8789133483617206, -3.4146482482723286]

# %%
np.sqrt(np.mean((test_y - predict) ** 2))
# Out:
# 2.1631650083081504

# %%
history
# Out:
#          USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0      007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1      007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2      007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3      008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4      008268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...       ...    ...                            ...  ...  ...   ...     ...
# 29605  A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606  A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607  A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
history.dtypes
# Out:
# USAF             object
# WBAN              int64
# STATION NAME     object
# CTRY             object
# ST               object
# CALL             object
# LAT             float64
# LON             float64
# ELEV(M)         float64
# BEGIN             int64
# END               int64
# dtype: object

# %%
stations_to_regions
# Out:
# {690014: 'west',
#  690020: 'west',
#  690070: 'west',
#  690090: 'south',
#  690110: 'midwest',
#  690140: 'west',
#  690150: 'west',
#  690170: 'west',
#  690174: 'west',
#  690190: 'south',
#  690200: 'south',
#  690210: 'south',
#  690220: 'south',
#  690230: 'west',
#  690240: 'west',
#  690250: 'south',
#  690260: 'midwest',
#  690280: 'south',
#  690290: 'south',
#  690310: 'west',
#  690320: 'west',
#  690330: 'west',
#  690500: 'south',
#  690524: 'south',
#  690584: 'west',
#  691164: 'south',
#  691174: 'south',
#  691224: 'west',
#  691324: 'south',
#  691334: 'west',
#  691414: 'west',
#  691484: 'west',
#  691804: 'south',
#  692364: 'west',
#  692494: 'west',
#  692534: 'south',
#  692584: 'west',
#  692644: 'midwest',
#  692694: 'west',
#  692704: 'south',
#  692754: 'south',
#  692764: 'south',
#  692784: 'west',
#  693254: 'south',
#  693654: 'west',
#  694300: 'west',
#  694604: 'west',
#  695354: 'south',
#  695364: 'south',
#  695414: 'west',
#  695424: 'west',
# ...

# %%
history['USAF'] = history['USAF'].apply(lambda usaf: usaf.strip('A')).apply(int)

# %%
history
# Out:
#         USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0       7018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1       7026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2       7070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3       8260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4       8268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...      ...    ...                            ...  ...  ...   ...     ...
# 29605   7355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606   7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607   7359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# ...

# %%
history.dtypes
# Out:
# USAF              int64
# WBAN              int64
# STATION NAME     object
# CTRY             object
# ST               object
# CALL             object
# LAT             float64
# LON             float64
# ELEV(M)         float64
# BEGIN             int64
# END               int64
# dtype: object

# %%
history['USAF']
# Out:
# 0         7018
# 1         7026
# 2         7070
# 3         8260
# 4         8268
#          ...
# 29605     7355
# 29606     7357
# 29607     7359
# 29608    51255
# 29609    51256
# Name: USAF, Length: 29610, dtype: int64

# %%
history['region'] = history['USAF'].apply(lambda usaf: stations_to_regions[usaf] if usaf in stations_to_regions else '')

# %%
history
# Out:
#         USAF   WBAN                   STATION NAME CTRY   ST  CALL     LAT  \
# 0       7018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000
# 1       7026  99999                     WXPOD 7026   AF  NaN   NaN   0.000
# 2       7070  99999                     WXPOD 7070   AF  NaN   NaN   0.000
# 3       8260  99999                      WXPOD8270  NaN  NaN   NaN   0.000
# 4       8268  99999                      WXPOD8278   AF  NaN   NaN  32.950
# ...      ...    ...                            ...  ...  ...   ...     ...
# 29605   7355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579
# 29606   7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986
# 29607   7359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938
# 29608  51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464
# 29609  51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END   region
# ...

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END   region
# ...

# %%
region_number = {'northeast': 'NE', 'south': 'S', 'midwest': 'MW', 'west': 'W'}

# %%
us_history['RGN'] = us_history['region'].apply(lambda region: region_number[region])
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/2366510224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_history['RGN'] = us_history['region'].apply(lambda region: region_number[region])

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END   region RGN
# ...

# %%
us_history['RGN'].unique()
# Out:
# array(['W', 'S', 'MW', 'NE'], dtype=object)

# %%
us_history.drop('region', axis = 1, inplace = True)
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/2688260719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_history.drop('region', axis = 1, inplace = True)

# %%
us_history
# Out:
#          USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 14498  690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 14499  690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14500  690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 14501  690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 14504  690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...       ...    ...                            ...  ...  ..   ...     ...
# 29605    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 29606    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 29607    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 29608   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 29609   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#            LON  ELEV(M)     BEGIN       END RGN
# ...

# %%
us_history.to_csv('us_history.csv', index = False)

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
df['region'].unique()
# Out:
# array(['', 'west', 'midwest', 'south', 'northeast'], dtype=object)

# %%
df = df.drop('region', axis = 1)

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
us_history = pd.read_csv('us_history.csv')

# %%
us_history
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 0     690014  99999             C STN  WHITE SANDS   US  NM   NaN  32.350
# 1     690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 2     690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 3     690070  93217                  FRITZSCHE AAF   US  CA  KOAR  36.683
# 4     690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# ...      ...    ...                            ...  ...  ..   ...     ...
# 6539    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 6540    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 6541    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 6542   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
# 6543   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END RGN
# ...

# %%
us_history.dtypes
# Out:
# USAF              int64
# WBAN              int64
# STATION NAME     object
# CTRY             object
# ST               object
# CALL             object
# LAT             float64
# LON             float64
# ELEV(M)         float64
# BEGIN             int64
# END               int64
# RGN              object
# dtype: object

# %%
us_history = us_history[['USAF', 'WBAN', 'STATION NAME', 'CTRY', 'ST', 'RGN', 'CALL', 'LAT', 'LON', 'ELEV(M)', 'BEGIN', 'END']]

# %%
us_history
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST RGN  CALL     LAT  \
# 0     690014  99999             C STN  WHITE SANDS   US  NM   W   NaN  32.350
# 1     690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 2     690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 3     690070  93217                  FRITZSCHE AAF   US  CA   W  KOAR  36.683
# 4     690090  99999           HURLBURT FLD/EXERCIS   US  FL   S   NaN  30.433
# ...      ...    ...                            ...  ...  ..  ..   ...     ...
# 6539    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  MW  KY51  43.579
# 6540    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  MW  KY63  45.986
# 6541    7359    240           IONIA COUNTY AIRPORT   US  MI  MW  KY70  42.938
# 6542   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL   S  KDYA  32.464
# 6543   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  MW  KFWB  36.699
#
# ...

# %%
us_history.to_csv('us_history.csv', index = False)

# %%
us_history
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST RGN  CALL     LAT  \
# 0     690014  99999             C STN  WHITE SANDS   US  NM   W   NaN  32.350
# 1     690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 2     690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 3     690070  93217                  FRITZSCHE AAF   US  CA   W  KOAR  36.683
# 4     690090  99999           HURLBURT FLD/EXERCIS   US  FL   S   NaN  30.433
# ...      ...    ...                            ...  ...  ..  ..   ...     ...
# 6539    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  MW  KY51  43.579
# 6540    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  MW  KY63  45.986
# 6541    7359    240           IONIA COUNTY AIRPORT   US  MI  MW  KY70  42.938
# 6542   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL   S  KDYA  32.464
# 6543   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  MW  KFWB  36.699
#
# ...

# %%
mw = df[df['RGN'] == 'MW'].drop('RGN', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RGN'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
s
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 4     690090  99999           HURLBURT FLD/EXERCIS   US  FL   NaN  30.433
# 11    690190  13910              ABILENE DYESS AFB   US  TX  KDYS  32.433
# 12    690190  99999              DYESS AFB/ABILENE   US  TX   NaN  32.417
# 13    690200  99999                  GOVERNOR HYDE   US  NC   NaN  35.250
# 14    690210  99999               ALLIGATOR BRIDGE   US  NC   NaN  35.900
# ...      ...    ...                            ...  ...  ..   ...     ...
# 6528    5735    209        BOWIE MUNICIPAL AIRPORT   US  TX  K0F2  33.600
# 6529    6773    334  TUCKER GUTHRIE MEMORIAL AIRPO   US  KY  KI35  36.859
# 6530    6800    120        TAZEWELL COUNTY AIRPORT   US  VA  KJFZ  37.067
# 6532    6884    416          LURAY CAVERNS AIRPORT   US  VA  KLUA  38.667
# 6542   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL  KDYA  32.464
#
#          LON  ELEV(M)     BEGIN       END
# ...

# %%
w
# Out:
#         USAF   WBAN                  STATION NAME CTRY  ST  CALL     LAT  \
# 0     690014  99999            C STN  WHITE SANDS   US  NM   NaN  32.350
# 1     690020  93218  JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 2     690020  99999  JOLON HUNTER LIGGETT MIL RES   US  CA  KHGT  36.000
# 3     690070  93217                 FRITZSCHE AAF   US  CA  KOAR  36.683
# 6     690140  93101                  EL TORO MCAS   US  CA  KNZJ  33.667
# ...      ...    ...                           ...  ...  ..   ...     ...
# 6523      28   4116    SALT LAKE CITY MUNI 2 ARPT   US  UT  KU42  40.619
# 6527      32  25715                  ATKA AIRPORT   US  AK  PAAK  52.220
# 6531    6854    115         BIG BEAR CITY AIRPORT   US  CA  KL35  34.264
# 6533    7049    320    PETALUMA MUNICIPAL AIRPORT   US  CA  KO69  38.250
# 6534    7053    346        TRINITY CENTER AIRPORT   US  CA  KO86  40.983
#
#           LON  ELEV(M)     BEGIN       END
# 0    -106.367   1224.0  19870101  19910611
# ...

# %%
ne
# Out:
#         USAF   WBAN                  STATION NAME CTRY  ST  CALL     LAT  \
# 570   720304  64752           WINGS FIELD AIRPORT   US  PA  KLOM  40.100
# 571   720304  99999                     WINGS FLD   US  PA  KLOM  40.133
# 608   720324  64753            QUAKERTOWN AIRPORT   US  PA  KUKT  40.435
# 609   720324  99999                    QUAKERTOWN   US  PA  KUKT  40.433
# 672   720378    122  NEW CASTLE MUNICIPAL AIRPORT   US  PA  KUCP  41.033
# ...      ...    ...                           ...  ...  ..   ...     ...
# 6477  999999  94789          NEW YORK FORT TOTTEN   US  NY  KJFK  40.639
# 6478  999999  94790                  WATERTOWN AP   US  NY  KART  43.992
# 6479  999999  94794        UTICA ONEIDA COUNTY AP   US  NY  KUCA  43.145
# 6489  999999  94868                      FRANKLIN   US  PA  KFKL  41.383
# 6525      30  93795         CONNELLSVILLE AIRPORT   US  PA  KVVS  39.959
#
#          LON  ELEV(M)     BEGIN       END
# 570  -75.267     92.1  20050101  20220428
# ...

# %%
mw
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST  CALL     LAT  \
# 5     690110  99999           SELFRIDGE ANGB/TRAIN   US  MI   NaN  42.608
# 19    690260  99999                      CHEBOYGAN   US  MI   NaN  45.650
# 40    692644  99999           MUSCATATUCK TRNG CTR   US  IN  KQMT  39.050
# 447   711680  99999            SIOUX FALLS CLIMATE   US  SD   NaN  43.733
# 455   720113  54829           OAKLAND/TROY AIRPORT   US  MI  KVLL  42.543
# ...      ...    ...                            ...  ...  ..   ...     ...
# 6538    7354    132      WAUTOMA MUNICIPAL AIRPORT   US  WI  KY50  44.033
# 6539    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  KY51  43.579
# 6540    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  KY63  45.986
# 6541    7359    240           IONIA COUNTY AIRPORT   US  MI  KY70  42.938
# 6543   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  KFWB  36.699
#
#          LON  ELEV(M)     BEGIN       END
# ...

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
us_history
# Out:
#         USAF   WBAN                   STATION NAME CTRY  ST RGN  CALL     LAT  \
# 0     690014  99999             C STN  WHITE SANDS   US  NM   W   NaN  32.350
# 1     690020  93218   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 2     690020  99999   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 3     690070  93217                  FRITZSCHE AAF   US  CA   W  KOAR  36.683
# 4     690090  99999           HURLBURT FLD/EXERCIS   US  FL   S   NaN  30.433
# ...      ...    ...                            ...  ...  ..  ..   ...     ...
# 6539    7355    241      VIROQUA MUNICIPAL AIRPORT   US  WI  MW  KY51  43.579
# 6540    7357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  MW  KY63  45.986
# 6541    7359    240           IONIA COUNTY AIRPORT   US  MI  MW  KY70  42.938
# 6542   51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US  AL   S  KDYA  32.464
# 6543   51256    451  BRANSON WEST MUNICIPAL EMERSO   US  MO  MW  KFWB  36.699
#
# ...

# %%
len(us_history['USAF'].unique())
# Out:
# 3784

# %%
3784 * 2
# Out:
# 7568

# %%
us_history.drop('WBAN', axis = 1, inplace = True)
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/1764894054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_history.drop('WBAN', axis = 1, inplace = True)

# %%
us_history
# Out:
#         USAF                   STATION NAME CTRY  ST RGN  CALL     LAT  \
# 0     690014             C STN  WHITE SANDS   US  NM   W   NaN  32.350
# 1     690020   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 2     690020   JOLON HUNTER LIGGETT MIL RES   US  CA   W  KHGT  36.000
# 3     690070                  FRITZSCHE AAF   US  CA   W  KOAR  36.683
# 4     690090           HURLBURT FLD/EXERCIS   US  FL   S   NaN  30.433
# ...      ...                            ...  ...  ..  ..   ...     ...
# 6539    7355      VIROQUA MUNICIPAL AIRPORT   US  WI  MW  KY51  43.579
# 6540    7357  ELBOW LAKE MUNICIPAL PRIDE OF   US  MN  MW  KY63  45.986
# 6541    7359           IONIA COUNTY AIRPORT   US  MI  MW  KY70  42.938
# 6542   51255    DEMOPOLIS MUNICIPAL AIRPORT   US  AL   S  KDYA  32.464
# 6543   51256  BRANSON WEST MUNICIPAL EMERSO   US  MO  MW  KFWB  36.699
#
#           LON  ELEV(M)     BEGIN       END
# 0    -106.367   1224.0  19870101  19910611
# ...

# %%
us_history.groupby('USAF').agg({
    'STATION NAME': 'first',
    'CTRY': 'first',
    'ST': 'first',
    'RGN': 'first',
    'CALL': 'first',
    'LAT': 'first',
    'LON': 'first',
    'ELEV(M)': 'first',
    'BEGIN': np.min,
    'END': np.max
}).reset_index()
# Out:
#         USAF                  STATION NAME CTRY  ST RGN  CALL     LAT  \
# 0          2     BRENHAM MUNICIPAL AIRPORT   US  TX   S  K11R  30.219
# 1          3          MACON COUNTY AIRPORT   US  NC   S  K1A5  35.223
# 2          4    ARDMORE DOWNTOWN EXEC ARPT   US  OK   S  K1F0  34.147
# 3          5     MC ELORY AIRFIELD AIRPORT   US  CO   W  K20V  40.054
# 4          8     FAYETTE RGNL AIR CNTR ARP   US  TX   S  K3T5  29.908
# ...      ...                           ...  ...  ..  ..   ...     ...
# 3779  998495            WHITE WATER - WEST   US  FL   S  None  25.230
# 3780  998496                       OAKLAND   US  CA   W  None  37.795
# 3781  998497            FOSTER AVE CHICAGO   US  IL  MW  None  41.976
# 3782  998499              NORTHERLY ISLAND   US  IL  MW  None  41.856
# 3783  999999  DEXTER B FLORENCE MEM FLD AP   US  AR   S  KLDJ  34.100
#
#           LON  ELEV(M)     BEGIN       END
# 0     -96.374     93.9  20060101  20220428
# ...

# %%
rgns = dict(zip(us_history['USAF'], us_history['RGN']))

# %%
rgns
# Out:
# {690014: 'W',
#  690020: 'W',
#  690070: 'W',
#  690090: 'S',
#  690110: 'MW',
#  690140: 'W',
#  690150: 'W',
#  690170: 'W',
#  690174: 'W',
#  690190: 'S',
#  690200: 'S',
#  690210: 'S',
#  690220: 'S',
#  690230: 'W',
#  690240: 'W',
#  690250: 'S',
#  690260: 'MW',
#  690280: 'S',
#  690290: 'S',
#  690310: 'W',
#  690320: 'W',
#  690330: 'W',
#  690500: 'S',
#  690524: 'S',
#  690584: 'W',
#  691164: 'S',
#  691174: 'S',
#  691224: 'W',
#  691324: 'S',
#  691334: 'W',
#  691414: 'W',
#  691484: 'W',
#  691804: 'S',
#  692364: 'W',
#  692494: 'W',
#  692534: 'S',
#  692584: 'W',
#  692644: 'MW',
#  692694: 'W',
#  692704: 'S',
#  692754: 'S',
#  692764: 'S',
#  692784: 'W',
#  693254: 'S',
#  693654: 'W',
#  694300: 'W',
#  694604: 'W',
#  695354: 'S',
#  695364: 'S',
#  695414: 'W',
#  695424: 'W',
#  696334: 'W',
#  696454: 'W',
#  696464: 'W',
#  697534: 'W',
#  697564: 'W',
#  698114: 'W',
#  698324: 'S',
#  698414: 'W',
#  699604: 'W',
#  700001: 'W',
#  700197: 'W',
# ...

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht
# ...

# %%
df['region'] = df['station_num'].apply(lambda station_num: rgns[station_num] if station_num in rgns else '')

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0               10590     10.1  2004      1    1    0     0     0     0
# 1               10590      8.0  2004      1    2    0     0     0     0
# 2               10590     -2.0  2004      1    3    0     0     0     0
# 3               10590      1.3  2004      1    4    0     0     0     0
# 4               10590      0.4  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42531152       350850    -14.2  2008     12   26    0     0     0     0
# 42531153       350850     -4.6  2008     12   28    1     0     0     0
# 42531154       350850      6.8  2008     12   29    1     0     0     0
# 42531155       350850      0.6  2008     12   30    0     0     0     0
# 42531156       350850      1.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
df['region'].unique()
# Out:
# array(['', 'W', 'MW', 'S', 'NE'], dtype=object)

# %%
df = df[df['region'] != '']

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527773       726558     30.5  2008     12   27    1     0     1     0
# 42527774       726558     11.7  2008     12   28    1     0     0     0
# 42527775       726558     15.6  2008     12   29    1     0     0     0
# 42527776       726558      6.0  2008     12   30    1     0     0     0
# 42527777       726558     -5.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region
# ...

# %%
regnums = {'NE': 0, 'S': 1, 'MW': 2, 'W': 3}

# %%
df['region2'] = df['region'].apply(lambda region: regnums[region])
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/625866636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['region2'] = df['region'].apply(lambda region: regnums[region])

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527773       726558     30.5  2008     12   27    1     0     1     0
# 42527774       726558     11.7  2008     12   28    1     0     0     0
# 42527775       726558     15.6  2008     12   29    1     0     0     0
# 42527776       726558      6.0  2008     12   30    1     0     0     0
# 42527777       726558     -5.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht region  \
# ...

# %%
df.drop('region2', axis = 1, inplace = True)
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/4167447924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('region2', axis = 1, inplace = True)

# %%
df['region'] = df['region2']
# Out:
# /var/folders/yq/0nx3ssmj049fgh1fl2ll33_80000gn/T/ipykernel_19403/4063356904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['region'] = df['region2']

# %%
df
# Out:
#           station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 336            700634     -0.4  2004      1    1    0     0     0     0
# 337            700634      4.9  2004      1    2    0     0     0     0
# 338            700634     20.6  2004      1    3    1     0     0     0
# 339            700634     21.4  2004      1    4    1     0     0     0
# 340            700634     11.3  2004      1    5    0     0     0     0
# ...               ...      ...   ...    ...  ...  ...   ...   ...   ...
# 42527773       726558     30.5  2008     12   27    1     0     1     0
# 42527774       726558     11.7  2008     12   28    1     0     0     0
# 42527775       726558     15.6  2008     12   29    1     0     0     0
# 42527776       726558      6.0  2008     12   30    1     0     0     0
# 42527777       726558     -5.7  2008     12   31    0     0     0     0
#
#           thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht  region
# ...

# %%
df.dtypes
# Out:
# station_num         int64
# temp_ft           float64
# year                int64
# month               int64
# day                 int64
# fog                 int64
# rain                int64
# snow                int64
# hail                int64
# thunder             int64
# tornado             int64
# precip_in         float64
# max_temp_frnht    float64
# min_temp_frnht    float64
# region              int64
# dtype: object

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#          station_num  temp_ft  year  month  day  fog  rain  snow  hail  \
# 0             700634     -0.4  2004      1    1    0     0     0     0
# 1             700634      4.9  2004      1    2    0     0     0     0
# 2             700634     20.6  2004      1    3    1     0     0     0
# 3             700634     21.4  2004      1    4    1     0     0     0
# 4             700634     11.3  2004      1    5    0     0     0     0
# ...              ...      ...   ...    ...  ...  ...   ...   ...   ...
# 8742806       726558     30.5  2008     12   27    1     0     1     0
# 8742807       726558     11.7  2008     12   28    1     0     0     0
# 8742808       726558     15.6  2008     12   29    1     0     0     0
# 8742809       726558      6.0  2008     12   30    1     0     0     0
# 8742810       726558     -5.7  2008     12   31    0     0     0     0
#
#          thunder  tornado  precip_in  max_temp_frnht  min_temp_frnht  region
# ...

# %%
df.to_csv('/Users/samerens/Downloads/usdf.csv', index = False)
